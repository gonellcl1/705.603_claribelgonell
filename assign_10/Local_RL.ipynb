# %% [markdown]
# ## EN.705.503.82 - AI-Enabled Systems: Local RL
#
# Claribel Gonell

# %% [markdown]
# Utilized Amazon Sagemaker examples with pre-set dqn module in attempt to directly use Blackjack.

# %% [markdown]
# ### Pre-requisites
#
# Importing relevant libraries for model configuration

# %%
import sagemaker
import boto3
import sys
import os
import glob
import re
import subprocess
from IPython.display import HTML
import time
from time import gmtime, strftime
import pandas as pd
sys.path.append("common")
from misc import get_execution_role, wait_for_s3_object
from sagemaker.rl import RLEstimator, RLToolkit, RLFramework

# install gym environments if needed

from env_utils import VectoredGymEnvironment

# %% [markdown]
# ### Setting Up S3 Bucket
#
# Linking AWS S3 bucket links for checkpoints and metadata

# %%
# S3 bucket
sage_session = sagemaker.session.Session()
s3_bucket = sage_session.default_bucket()
region_name = sage_session.boto_region_name
s3_output_path = "s3://{}/".format(s3_bucket)  # SDK appends the job name and output folder
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-us-west-2-947824586777/

# %% [markdown]
# ### Unique Job Name for training jobs and image path for container

# %%
# create unique job name
job_name_prefix = "rl-batch-blackjack"

# %% [markdown]
# ### Configuring Settings
#
# Local Mode: utilitzes SageMaker Python SDK to run code locally to prepare for Sagemaker deployment

# %%
# %%time

# run in local mode?
local_mode = True
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.39 µs

# %% [markdown]
# ### Setting Up IAM Role
#
# AWS: execution role from Sagemaker notebook
# Local: uses utils method for local machine

# %%
try:
    role = sagemaker.get_execution_role()
except:
    role = get_execution_role()

print("Using IAM role arn: {}".format(role))
# Out:
# Using IAM role arn: arn:aws:iam::947824586777:role/service-role/AmazonSageMaker-ExecutionRole-20221116T205015

# %% [markdown]
# ### Docker installation for local mode
#
# Common Folder has been copied into AWS Juypter notebook files which contains a setup.sh file initalizes local CPU or local CPU machine.

# %%
# only run from SageMaker notebook instance
if local_mode:
    # !/bin/bash ./common/setup.sh
# Out:
# The user has root access.
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %% [markdown]
# ### Presets for RL Algorithm Configuration
#
# Presets: Batch RL trianing job defined using a DDQ instance
#
# 1. Graph Scheduling parameters
# 2. Agent Parameters (DQN Agent Parameters)
# 3. DQN Parameters
# 4. Network wrapper configuration
# 5. ER size
# 6. E-Greedy Schedule
# 7. Enviornment = Gym Vector Environment
# 8. Visualization = initialized Visualization Parameters
# 9. Test Parameters
# 10. Graph Manager

# %%
# !pygmentize src/preset-blackjack-ddqnbcq.py
# Out:
# from rl_coach.agents.ddqn_bcq_agent import DDQNBCQAgentParameters, KNNParameters
# from rl_coach.base_parameters import PresetValidationParameters, VisualizationParameters, TaskParameters
# from rl_coach.core_types import (
#     CsvDataset,
#     EnvironmentEpisodes,
#     EnvironmentSteps,
#     RunPhase,
#     TrainingSteps,
# )
# from rl_coach.environments.gym_environment import GymVectorEnvironment, mujoco_v2
# from rl_coach.graph_managers.batch_rl_graph_manager import BatchRLGraphManager
# from rl_coach.graph_managers.graph_manager import ScheduleParameters
# from rl_coach.memories.episodic import EpisodicExperienceReplayParameters
# from rl_coach.schedules import LinearSchedule
# from rl_coach.spaces import (
#     DiscreteActionSpace,
#     RewardSpace,
#     SpacesDefinition,
#     StateSpace,
#     VectorObservationSpace,
# )
#
# # ####################
# # # Graph Scheduling #
# # ####################
#
# schedule_params = ScheduleParameters()
# # 50 epochs (we run train over all the dataset, every epoch) of training
# schedule_params.improve_steps = TrainingSteps(50)
# # we evaluate the model every epoch
# schedule_params.steps_between_evaluation_periods = TrainingSteps(1)
#
# #########
# # Agent #
# #########
# # note that we have moved to BCQ, which will help the training to converge better and faster
# agent_params = DDQNBCQAgentParameters()
# agent_params.network_wrappers["main"].batch_size = 128
# agent_params.algorithm.num_steps_between_copying_online_weights_to_target = TrainingSteps(50)
# agent_params.algorithm.discount = 0.99
#
# # NN configuration
# agent_params.network_wrappers["main"].learning_rate = 0.0001
# agent_params.network_wrappers["main"].replace_mse_with_huber_loss = False
#
# # ER - we'll be needing an episodic replay buffer for off-policy evaluation
# agent_params.memory = EpisodicExperienceReplayParameters()
#
# # E-Greedy schedule - there is no exploration in Batch RL. Disabling E-Greedy.
# agent_params.exploration.epsilon_schedule = LinearSchedule(
#     initial_value=0.99, final_value=0.02, decay_steps=1
# )
# agent_params.exploration.evaluation_epsilon = 0
#
# # can use either a kNN or a NN based model for predicting which actions not to max over in the bellman equation
# agent_params.algorithm.action_drop_method_parameters = KNNParameters()
#
# ###########
# # Dataset #
# ###########
# DATATSET_PATH = "blackjack_dataset.csv"
# agent_params.memory = EpisodicExperienceReplayParameters()
# agent_params.memory.load_memory_from_file_path = CsvDataset(DATATSET_PATH, is_episodic=True)
#
# spaces = SpacesDefinition(
#     state=StateSpace({"observation": VectorObservationSpace(shape=3)}),
#     goal=None,
#     action=DiscreteActionSpace(2),
#     reward=RewardSpace(1),
# )
#
# #################
# # Visualization #
# #################
#
# vis_params = VisualizationParameters()
# vis_params.dump_gifs = True
#
# ########
# # Test #
# ########
# preset_validation_params = PresetValidationParameters()
# preset_validation_params.test = True
# preset_validation_params.min_reward_threshold = 150
# preset_validation_params.max_episodes_to_achieve_reward = 250
#
#
# env_params = GymVectorEnvironment(level="Blackjack-v0")
#
# graph_manager = BatchRLGraphManager(
#     agent_params=agent_params,
#     env_params=None,
#     spaces_definition=spaces,
#     schedule_params=schedule_params,
#     vis_params=vis_params,
#     reward_model_num_epochs=30,
#     train_to_eval_ratio=0.4,
#     preset_validation_params=preset_validation_params,
# )

# %% [markdown]
# ## Training Main()
# imports environment, preset files, and defines main().

# %%
# !pygmentize src/train-coach.py
# Out:
# import shutil
#
# from sagemaker_rl.coach_launcher import SageMakerCoachPresetLauncher
#
#
# class MyLauncher(SageMakerCoachPresetLauncher):
#     def default_preset_name(self):
#         """This points to a .py file that configures everything about the RL job.
#         It can be overridden at runtime by specifying the RLCOACH_PRESET hyperparameter.
#         """
#         return "preset-blackjack-ddqnbcq"
#
#     def map_hyperparameter(self, name, value):
#         """Here we configure some shortcut names for hyperparameters that we expect to use frequently.
#         Essentially anything in the preset file can be overridden through a hyperparameter with a name
#         like "rl.agent_params.algorithm.etc".
#         """
#         # maps from alias (key) to fully qualified coach parameter (value)
#         mapping = {
#             "discount": "rl.agent_params.algorithm.discount",
#             "evaluation_episodes": "rl.evaluation_steps:EnvironmentEpisodes",
#             "improve_steps": "rl.improve_steps:TrainingSteps",
#         }
#         if name in mapping:
#             self.apply_hyperparameter(mapping[name], value)
#         else:
#             super().map_hyperparameter(name, value)
#
#     def _save_tf_model(self):
#         import tensorflow as tf
#
#         ckpt_dir = "/opt/ml/output/data/checkpoint"
#         model_dir = "/opt/ml/model"
#
#         # Re-Initialize from the checkpoint so that you will have the latest models up.
#         tf.train.init_from_checkpoint(
#             ckpt_dir, {"main_level/agent/online/network_0/": "main_level/agent/online/network_0"}
#         )
#         tf.train.init_from_checkpoint(
#             ckpt_dir, {"main_level/agent/online/network_1/": "main_level/agent/online/network_1"}
#         )
#
#         # Create a new session with a new tf graph.
#         sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
#         sess.run(tf.global_variables_initializer())  # initialize the checkpoint.
#
#         # print([n.name for n in tf.get_default_graph().as_graph_def().node])
#         # This is the node that will accept the input.
#         input_nodes = tf.get_default_graph().get_tensor_by_name(
#             "main_level/agent/main/online/" + "network_0/observation/observation:0"
#         )
#         # This is the node that will produce the output.
#         output_nodes = tf.get_default_graph().get_operation_by_name(
#             "main_level/agent/main/online/" + "network_0/q_values_head_0/softmax"
#         )
#         # Save the model as a servable model.
#         tf.saved_model.simple_save(
#             session=sess,
#             export_dir="model",
#             inputs={"observation": input_nodes},
#             outputs={"policy": output_nodes.outputs[0]},
#         )
#         # Move to the appropriate folder.
#         shutil.move("model/", model_dir + "/model/tf-model/00000001/")
#         # SageMaker will pick it up and upload to the right path.
#         print("Success")
#
#
# if __name__ == "__main__":
#     MyLauncher.train_main()

# %% [markdown]
# ### Batch RL training with generated deployed policy.
#
# Successfully created 100 environments and generated a random policy with uniform probablities.
#
# The code was adapted from: https://github.com/aws/amazon-sagemaker-examples/blob/main/reinforcement_learning/rl_cartpole_batch_coach/rl_cartpole_batch_coach.ipynb
#
# Example code:

# %% [markdown]
# ![Screen%20Shot%202022-11-19%20at%205.06.07%20PM.png](attachment:Screen%20Shot%202022-11-19%20at%205.06.07%20PM.png)

# %% [markdown]
# ### Python SDK Script Mode Training
#
# Will produce error due to incapable input

# %%
# %%time

if local_mode:
    instance_type = "local"
else:
    instance_type = "ml.m4.xlarge"

estimator = RLEstimator(
    entry_point="train-coach.py",
    source_dir="src",
    dependencies=["sagemaker_rl"],
    toolkit=RLToolkit.COACH,
    toolkit_version="1.0.0",
    framework=RLFramework.TENSORFLOW,
    role=role,
    instance_type=instance_type,
    instance_count=1,
    output_path=s3_output_path,
    base_job_name=job_name_prefix,
    hyperparameters={"RLCOACH_PRESET": "preset-blackjack-ddqnbcq", "save_model": 1},
)
estimator.fit()
# Out:
# Creating 9pu4pir1uo-algo-1-q8lbv ...
# Creating 9pu4pir1uo-algo-1-q8lbv ... done
# Attaching to 9pu4pir1uo-algo-1-q8lbv
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,523 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,531 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,734 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,752 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,770 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:09,782 sagemaker-containers INFO     Invoking user script
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | Training Env:
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | {
# 9pu4pir1uo-algo-1-q8lbv |     "additional_framework_parameters": {
# 9pu4pir1uo-algo-1-q8lbv |         "sagemaker_estimator": "RLEstimator"
# 9pu4pir1uo-algo-1-q8lbv |     },
# 9pu4pir1uo-algo-1-q8lbv |     "channel_input_dirs": {},
# 9pu4pir1uo-algo-1-q8lbv |     "current_host": "algo-1-q8lbv",
# 9pu4pir1uo-algo-1-q8lbv |     "framework_module": "sagemaker_tensorflow_container.training:main",
# 9pu4pir1uo-algo-1-q8lbv |     "hosts": [
# 9pu4pir1uo-algo-1-q8lbv |         "algo-1-q8lbv"
# 9pu4pir1uo-algo-1-q8lbv |     ],
# 9pu4pir1uo-algo-1-q8lbv |     "hyperparameters": {
# 9pu4pir1uo-algo-1-q8lbv |         "RLCOACH_PRESET": "preset-blackjack-ddqnbcq",
# 9pu4pir1uo-algo-1-q8lbv |         "save_model": 1
# 9pu4pir1uo-algo-1-q8lbv |     },
# 9pu4pir1uo-algo-1-q8lbv |     "input_config_dir": "/opt/ml/input/config",
# 9pu4pir1uo-algo-1-q8lbv |     "input_data_config": {},
# 9pu4pir1uo-algo-1-q8lbv |     "input_dir": "/opt/ml/input",
# 9pu4pir1uo-algo-1-q8lbv |     "is_master": true,
# 9pu4pir1uo-algo-1-q8lbv |     "job_name": "rl-batch-blackjack-2022-11-19-23-11-02-961",
# 9pu4pir1uo-algo-1-q8lbv |     "log_level": 20,
# 9pu4pir1uo-algo-1-q8lbv |     "master_hostname": "algo-1-q8lbv",
# 9pu4pir1uo-algo-1-q8lbv |     "model_dir": "/opt/ml/model",
# 9pu4pir1uo-algo-1-q8lbv |     "module_dir": "s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/source/sourcedir.tar.gz",
# 9pu4pir1uo-algo-1-q8lbv |     "module_name": "train-coach",
# 9pu4pir1uo-algo-1-q8lbv |     "network_interface_name": "eth0",
# 9pu4pir1uo-algo-1-q8lbv |     "num_cpus": 2,
# 9pu4pir1uo-algo-1-q8lbv |     "num_gpus": 0,
# 9pu4pir1uo-algo-1-q8lbv |     "output_data_dir": "/opt/ml/output/data",
# 9pu4pir1uo-algo-1-q8lbv |     "output_dir": "/opt/ml/output",
# 9pu4pir1uo-algo-1-q8lbv |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 9pu4pir1uo-algo-1-q8lbv |     "resource_config": {
# 9pu4pir1uo-algo-1-q8lbv |         "current_host": "algo-1-q8lbv",
# 9pu4pir1uo-algo-1-q8lbv |         "hosts": [
# 9pu4pir1uo-algo-1-q8lbv |             "algo-1-q8lbv"
# 9pu4pir1uo-algo-1-q8lbv |         ]
# 9pu4pir1uo-algo-1-q8lbv |     },
# 9pu4pir1uo-algo-1-q8lbv |     "user_entry_point": "train-coach.py"
# 9pu4pir1uo-algo-1-q8lbv | }
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | Environment variables:
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | SM_HOSTS=["algo-1-q8lbv"]
# 9pu4pir1uo-algo-1-q8lbv | SM_NETWORK_INTERFACE_NAME=eth0
# 9pu4pir1uo-algo-1-q8lbv | SM_HPS={"RLCOACH_PRESET":"preset-blackjack-ddqnbcq","save_model":1}
# 9pu4pir1uo-algo-1-q8lbv | SM_USER_ENTRY_POINT=train-coach.py
# 9pu4pir1uo-algo-1-q8lbv | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# 9pu4pir1uo-algo-1-q8lbv | SM_RESOURCE_CONFIG={"current_host":"algo-1-q8lbv","hosts":["algo-1-q8lbv"]}
# 9pu4pir1uo-algo-1-q8lbv | SM_INPUT_DATA_CONFIG={}
# 9pu4pir1uo-algo-1-q8lbv | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 9pu4pir1uo-algo-1-q8lbv | SM_CHANNELS=[]
# 9pu4pir1uo-algo-1-q8lbv | SM_CURRENT_HOST=algo-1-q8lbv
# 9pu4pir1uo-algo-1-q8lbv | SM_MODULE_NAME=train-coach
# 9pu4pir1uo-algo-1-q8lbv | SM_LOG_LEVEL=20
# 9pu4pir1uo-algo-1-q8lbv | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# 9pu4pir1uo-algo-1-q8lbv | SM_INPUT_DIR=/opt/ml/input
# 9pu4pir1uo-algo-1-q8lbv | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 9pu4pir1uo-algo-1-q8lbv | SM_OUTPUT_DIR=/opt/ml/output
# 9pu4pir1uo-algo-1-q8lbv | SM_NUM_CPUS=2
# 9pu4pir1uo-algo-1-q8lbv | SM_NUM_GPUS=0
# 9pu4pir1uo-algo-1-q8lbv | SM_MODEL_DIR=/opt/ml/model
# 9pu4pir1uo-algo-1-q8lbv | SM_MODULE_DIR=s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/source/sourcedir.tar.gz
# 9pu4pir1uo-algo-1-q8lbv | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1-q8lbv","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-q8lbv"],"hyperparameters":{"RLCOACH_PRESET":"preset-blackjack-ddqnbcq","save_model":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"rl-batch-blackjack-2022-11-19-23-11-02-961","log_level":20,"master_hostname":"algo-1-q8lbv","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/source/sourcedir.tar.gz","module_name":"train-coach","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-q8lbv","hosts":["algo-1-q8lbv"]},"user_entry_point":"train-coach.py"}
# 9pu4pir1uo-algo-1-q8lbv | SM_USER_ARGS=["--RLCOACH_PRESET","preset-blackjack-ddqnbcq","--save_model","1"]
# 9pu4pir1uo-algo-1-q8lbv | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 9pu4pir1uo-algo-1-q8lbv | SM_HP_RLCOACH_PRESET=preset-blackjack-ddqnbcq
# 9pu4pir1uo-algo-1-q8lbv | SM_HP_SAVE_MODEL=1
# 9pu4pir1uo-algo-1-q8lbv | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | Invoking script with the following command:
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | /usr/bin/python train-coach.py --RLCOACH_PRESET preset-blackjack-ddqnbcq --save_model 1
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv |
# 9pu4pir1uo-algo-1-q8lbv | Loading preset preset-blackjack-ddqnbcq from /opt/ml/code
# 9pu4pir1uo-algo-1-q8lbv | ## Creating graph - name: BatchRLGraphManager
# 9pu4pir1uo-algo-1-q8lbv | ## Creating agent - name: agent
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# 9pu4pir1uo-algo-1-q8lbv | /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# 9pu4pir1uo-algo-1-q8lbv |   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 9pu4pir1uo-algo-1-q8lbv | ## Loading a replay buffer from a CSV file. CSV file path: blackjack_dataset.csv
# Progress: (500/500) Time: 0.66 sec 100%|##########|
# 9pu4pir1uo-algo-1-q8lbv | ## Training a regression model for estimating MDP rewards
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=0, Reward Model Loss=0.001525628919664182
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=1, Reward Model Loss=0.00024341963427631477
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=2, Reward Model Loss=0.00029180515067357763
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=3, Reward Model Loss=0.0006602722171105837
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=4, Reward Model Loss=0.0006306939023105722
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=5, Reward Model Loss=0.0003444433555399117
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=6, Reward Model Loss=9.338568136292069e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=7, Reward Model Loss=3.5825718537365136e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=8, Reward Model Loss=0.00014333885261102726
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=9, Reward Model Loss=0.00026287670296273733
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=10, Reward Model Loss=0.00027538353185120384
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=11, Reward Model Loss=0.00018453779385278098
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=12, Reward Model Loss=7.144332936915912e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=13, Reward Model Loss=1.5548775033829243e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=14, Reward Model Loss=4.05798997043779e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=15, Reward Model Loss=0.00010603426122351696
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=16, Reward Model Loss=0.00014737389344525966
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=17, Reward Model Loss=0.00013184459193756707
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=18, Reward Model Loss=7.687632215062254e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=19, Reward Model Loss=2.5643887439448582e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=20, Reward Model Loss=1.1012415358747699e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=21, Reward Model Loss=3.338145937672571e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=22, Reward Model Loss=6.496459000596875e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=23, Reward Model Loss=7.587301201726262e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=24, Reward Model Loss=5.8105301209970527e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=25, Reward Model Loss=2.7956876070483733e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=26, Reward Model Loss=9.025833845187567e-06
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=27, Reward Model Loss=1.252334837581178e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=28, Reward Model Loss=2.9973921635629314e-05
# 9pu4pir1uo-algo-1-q8lbv | Training Batch RL Models> Epoch=29, Reward Model Loss=4.277947530346481e-05
# 9pu4pir1uo-algo-1-q8lbv | Traceback (most recent call last):
# 9pu4pir1uo-algo-1-q8lbv |   File "train-coach.py", line 70, in <module>
# 9pu4pir1uo-algo-1-q8lbv |     MyLauncher.train_main()
# 9pu4pir1uo-algo-1-q8lbv |   File "/opt/ml/code/sagemaker_rl/coach_launcher.py", line 277, in train_main
# 9pu4pir1uo-algo-1-q8lbv |     trainer.launch()
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/coach.py", line 224, in launch
# 9pu4pir1uo-algo-1-q8lbv |     self.run_graph_manager(graph_manager, args)
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/coach.py", line 610, in run_graph_manager
# 9pu4pir1uo-algo-1-q8lbv |     self.start_single_threaded(task_parameters, graph_manager, args)
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/coach.py", line 672, in start_single_threaded
# 9pu4pir1uo-algo-1-q8lbv |     start_graph(graph_manager=graph_manager, task_parameters=task_parameters)
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/coach.py", line 87, in start_graph
# 9pu4pir1uo-algo-1-q8lbv |     graph_manager.improve()
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/graph_managers/batch_rl_graph_manager.py", line 215, in improve
# 9pu4pir1uo-algo-1-q8lbv |     self.initialize_ope_models_and_stats()
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/graph_managers/batch_rl_graph_manager.py", line 260, in initialize_ope_models_and_stats
# 9pu4pir1uo-algo-1-q8lbv |     agent.improve_reward_model(epochs=self.reward_model_num_epochs)
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/agents/ddqn_bcq_agent.py", line 203, in improve_reward_model
# 9pu4pir1uo-algo-1-q8lbv |     state_embeddings = self.embedding([transition.state for transition in self.memory.transitions
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/agents/ddqn_bcq_agent.py", line 89, in to_embedding
# 9pu4pir1uo-algo-1-q8lbv |     states = self.prepare_batch_for_inference(states, 'reward_model')
# 9pu4pir1uo-algo-1-q8lbv |   File "/usr/local/lib/python3.6/dist-packages/rl_coach/agents/agent.py", line 810, in prepare_batch_for_inference
# 9pu4pir1uo-algo-1-q8lbv |     if key in states[0].keys():
# 9pu4pir1uo-algo-1-q8lbv | IndexError: list index out of range
# 9pu4pir1uo-algo-1-q8lbv | 2022-11-19 23:11:20,023 sagemaker-containers ERROR    ExecuteUserScriptError:
# 9pu4pir1uo-algo-1-q8lbv | Command "/usr/bin/python train-coach.py --RLCOACH_PRESET preset-blackjack-ddqnbcq --save_model 1"
# 9pu4pir1uo-algo-1-q8lbv exited with code 1
# 1
# Aborting on container exit...
# Failed to delete: /tmp/tmp30kiqxq6/algo-1-q8lbv Please remove it manually.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, environment, job_name)
#     247         try:
# --> 248             _stream_output(process)
#     249         except RuntimeError as e:
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/local/image.py in _stream_output(process)
#     915     if exit_code != 0:
# --> 916         raise RuntimeError("Process exited with code: %s" % exit_code)
#     917
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/workflow/pipeline_context.py in wrapper(*args, **kwargs)
#     270             return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
#     271
# --> 272         return run_func(*args, **kwargs)
#     273
#     274     return wrapper
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#    1123         self._prepare_for_training(job_name=job_name)
#    1124
# -> 1125         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#    1126         self.jobs.append(self.latest_training_job)
#    1127         if wait:
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    2040         train_args = cls._get_train_args(estimator, inputs, experiment_config)
#    2041
# -> 2042         estimator.sagemaker_session.train(**train_args)
#    2043
#    2044         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy)
#     611             self.sagemaker_client.create_training_job(**request)
#     612
# --> 613         self._intercept_create_request(train_request, submit, self.train.__name__)
#     614
#     615     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/session.py in _intercept_create_request(self, request, create, func_name)
#    4342             func_name (str): the name of the function needed intercepting
#    4343         """
# -> 4344         return create(request)
#    4345
#    4346
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/session.py in submit(request)
#     609             LOGGER.info("Creating training-job with name: %s", job_name)
#     610             LOGGER.debug("train request: %s", json.dumps(request, indent=4))
# --> 611             self.sagemaker_client.create_training_job(**request)
#     612
#     613         self._intercept_create_request(train_request, submit, self.train.__name__)
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, Environment, **kwargs)
#     192         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     193         logger.info("Starting training job")
# --> 194         training_job.start(
#     195             InputDataConfig, OutputDataConfig, hyperparameters, Environment, TrainingJobName
#     196         )
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, environment, job_name)
#     241         self.environment = environment
#     242
# --> 243         self.model_artifacts = self.container.train(
#     244             input_data_config, output_data_config, hyperparameters, environment, job_name
#     245         )
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, environment, job_name)
#     251             # which contains the exit code and append the command line to it.
#     252             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 253             raise RuntimeError(msg)
#     254         finally:
#     255             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmp30kiqxq6/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1

# %% [markdown]
# ### If executed correctly, would have stored training output and model checkpoints
#
#
# Necessary for metrics vizualization and model evaluation steps

# %%
job_name = estimator._current_job_name
print("Job name: {}".format(job_name))

s3_url = "s3://{}/{}".format(s3_bucket, job_name)

if local_mode:
    output_tar_key = "{}/output.tar.gz".format(job_name)
else:
    output_tar_key = "{}/output/output.tar.gz".format(job_name)

intermediate_folder_key = "{}/output/intermediate/".format(job_name)
output_url = "s3://{}/{}".format(s3_bucket, output_tar_key)
intermediate_url = "s3://{}/{}".format(s3_bucket, intermediate_folder_key)

print("S3 job path: {}".format(s3_url))
print("Output.tar.gz location: {}".format(output_url))
print("Intermediate folder path: {}".format(intermediate_url))

tmp_dir = "/tmp/{}".format(job_name)
os.system("mkdir {}".format(tmp_dir))
print("Create local folder {}".format(tmp_dir))
# Out:
# Job name: rl-batch-blackjack-2022-11-19-23-11-02-961
# S3 job path: s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961
# Output.tar.gz location: s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/output.tar.gz
# Intermediate folder path: s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/output/intermediate/
# Create local folder /tmp/rl-batch-blackjack-2022-11-19-23-11-02-961

# %% [markdown]
# ### Plots metrics for training jobs
#
# Off Policy Evalutation metric of training data to vizualize model performance over time.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

csv_file_name = "worker_0.batch_rl_graph.main_level.main_level.agent_0.csv"
key = os.path.join(intermediate_folder_key, csv_file_name)
wait_for_s3_object(s3_bucket, key, tmp_dir, training_job_name=job_name)

csv_file = "{}/{}".format(tmp_dir, csv_file_name)
df = pd.read_csv(csv_file)
df = df.dropna(subset=["Sequential Doubly Robust"])
df.dropna(subset=["Weighted Importance Sampling"])

plt.figure(figsize=(12, 5))
plt.xlabel("Number of epochs")

ax1 = df["Weighted Importance Sampling"].plot(color="blue", grid=True, label="WIS")
ax2 = df["Sequential Doubly Robust"].plot(color="red", grid=True, secondary_y=True, label="SDR")

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()

plt.legend(h1 + h2, l1 + l2, loc=1)
plt.show()
# Out:
# Waiting for s3://sagemaker-us-west-2-947824586777/rl-batch-blackjack-2022-11-19-23-11-02-961/output/intermediate/worker_0.batch_rl_graph.main_level.main_level.agent_0.csv....
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_7791/2316447950.py in <cell line: 7>()
#       5 csv_file_name = "worker_0.batch_rl_graph.main_level.main_level.agent_0.csv"
#       6 key = os.path.join(intermediate_folder_key, csv_file_name)
# ----> 7 wait_for_s3_object(s3_bucket, key, tmp_dir, training_job_name=job_name)
#       8
#       9 csv_file = "{}/{}".format(tmp_dir, csv_file_name)
#
# ~/SageMaker/common/misc.py in wait_for_s3_object(s3_bucket, key, local_dir, local_prefix, aws_account, aws_region, timeout, limit, fetch_only, training_job_name)
#      85             )
#      86         if training_job_name:
# ---> 87             training_job_status = sagemaker.describe_training_job(
#      88                 TrainingJobName=training_job_name
#      89             )["TrainingJobStatus"]
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     393                     "%s() only accepts keyword arguments." % py_operation_name)
#     394             # The "self" in this scope is referring to the BaseClient.
# --> 395             return self._make_api_call(operation_name, kwargs)
#     396
#     397         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     723             error_code = parsed_response.get("Error", {}).get("Code")
#     724             error_class = self.exceptions.from_code(error_code)
# --> 725             raise error_class(parsed_response, operation_name)
#     726         else:
#     727             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DescribeTrainingJob operation: Requested resource not found.
